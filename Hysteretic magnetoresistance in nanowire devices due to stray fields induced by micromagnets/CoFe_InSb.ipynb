# %%
#---------------------------------------------------------------------------------------------------------#
#----------------------------Created by Jiang, Yifan (姜一帆), 06/24/2020----------------------------------#
#---------------------------------An Interactive Version of the Paper-------------------------------------# 
#------'Hysteretic magnetoresistance in nanowire devices due to stray fields induced by micromagnets'-----#                                       # 
#---------------------------------------------------------------------------------------------------------#
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpldatacursor import datacursor
from ipysheet import sheet, cell, row, column, cell_range,from_dataframe,to_dataframe
import ipywidgets as widgets
from IPython.display import Image
import matplotlib.image as mpimg
import math

# %%
df869 = pd.read_csv("Fig.1(c)\data_869.dat",engine='python',skiprows=34,header=None,sep='\s+')
df869.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']
df870 = pd.read_csv("Fig.1(c)\data_870.dat",engine='python',skiprows=34,header=None,sep='\s+')
df870.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']

df755 = pd.read_csv("Fig.1(d)\data_755.dat",engine='python',skiprows=34,header=None,sep='\s+')
df755.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']
df756 = pd.read_csv("Fig.1(d)\data_756.dat",engine='python',skiprows=34,header=None,sep='\s+')
df756.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']

# %%
fig1 = plt.figure(figsize=(9,9))

ax1a = fig1.add_axes([0.06, 0.6, 0.45, 0.45])
ax1b = fig1.add_axes([0.06, 0.165, 0.45, 0.45])

ax1c = fig1.add_axes([0.6, 0.67, 0.3, 0.3])
ax1d = fig1.add_axes([0.6, 0.25, 0.3, 0.3])


ax1a.imshow(mpimg.imread('Fig.1(a)/1.12(a).png'))
ax1a.set_title('(a)')
ax1a.axis('off')

ax1b.imshow(mpimg.imread('Fig.1(a)/1.12(b).png'))
ax1b.set_title('(b)')
ax1b.axis('off')

ax1c.plot(df869['B (T)'],df869['Keithley 1'],df870['B (T)'],df870['Keithley 1'])
ax1c.legend(['-->','<--'])
ax1c.set_xlabel('B (T)')
ax1c.set_ylabel('I ($\mu$A)')
ax1c.set_title('(c)')


ax1d.plot(df755['B (T)'],df755['Keithley 1'],df756['B (T)'],df756['Keithley 1'])
ax1d.legend(['-->','<--'])
ax1d.set_xlabel('B (T)')
ax1d.set_ylabel('I ($\mu$A)')
ax1d.set_title('(d)')

datacursor()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
df850 = pd.read_csv("Fig.2(c,d)\data_850.dat",engine='python',skiprows=34,header=None,sep='\s+')
df850.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','lockin 2']
df851 = pd.read_csv("Fig.2(c,d)\data_851.dat",engine='python',skiprows=34,header=None,sep='\s+')
df851.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','lockin 2']

df1055 = pd.read_csv("Fig.2(e,f)\data_1055.dat",engine='python',skiprows=34,header=None,sep='\s+')
df1055.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','lockin 2']
df1056 = pd.read_csv("Fig.2(e,f)\data_1056.dat",engine='python',skiprows=34,header=None,sep='\s+')
df1056.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','lockin 2']

# %%
fig2 = plt.figure(figsize=(9,12))

ax2a = fig2.add_axes([0.09, 0.7, 0.3, 0.3])
ax2b = fig2.add_axes([0.48, 0.64, 0.45, 0.45])

ax2c = fig2.add_axes([0.09, 0.45, 0.3, 0.3*3/4])
ax2d = fig2.add_axes([0.09, 0.15, 0.3, 0.3*3/4])
ax2e = fig2.add_axes([0.55, 0.45, 0.3, 0.3*3/4])
ax2f = fig2.add_axes([0.55, 0.15, 0.3, 0.3*3/4])

Vac2 = 0.1/1000;
G0 = 7.74809173 * 10**(-5);

ax2a.imshow(mpimg.imread('Fig.2(a)/1.34(a).png'))
ax2a.set_title('(a)')
ax2a.axis('off')

ax2b.imshow(mpimg.imread('Fig.2(a)/1.34(b).png'))
ax2b.set_title('(b)')
ax2b.axis('off')

ax2c.plot(df850['B (T)'],df850['lockin 1']/(10**6)/Vac2/G0,df851['B (T)'],df851['lockin 1']/(10**6)/Vac2/G0)
ax2c.legend(['-->','<--'])
ax2c.set_xlabel('B (T)')
ax2c.set_ylabel('$G^{L}_{1-3}$ ($2e^{2}/h$)')
ax2c.set_title('(c)')

ax2d.plot(df850['B (T)'],df850['lockin 2']*(10**6),df851['B (T)'],df851['lockin 2']*(10**6))
ax2d.legend(['-->','<--'])
ax2d.set_xlabel('B (T)')
ax2d.set_ylabel('$V^{N}_{2-4}$ ($\mu$V)')
ax2d.set_title('(d)')

ax2e.plot(df1055['B (T)'],df1055['lockin 1']/(10**6)/Vac2/G0,df1056['B (T)'],df1056['lockin 1']/(10**6)/Vac2/G0)
ax2e.legend(['-->','<--'])
ax2e.set_xlabel('B (T)')
ax2e.set_ylabel('$G^{L}_{2-4}$ ($2e^{2}/h$)')
ax2e.set_title('(e)')

ax2f.plot(df1055['B (T)'],df1055['lockin 2']*(10**6),df1056['B (T)'],df1056['lockin 2']*(10**6))
ax2f.legend(['-->','<--'])
ax2f.set_xlabel('B (T)')
ax2f.set_ylabel('$V^{N}_{1-3}$ ($\mu$V)')
ax2f.set_title('(f)')




datacursor()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
df3332 = pd.read_csv("Fig.3(c)\data_3332.dat",engine='python',skiprows=34,header=None,sep='\s+')
df3332.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']
df3333 = pd.read_csv("Fig.3(c)\data_3333.dat",engine='python',skiprows=34,header=None,sep='\s+')
df3333.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']

df3344 = pd.read_csv("Fig.3(d)\data_3344.dat",engine='python',skiprows=34,header=None,sep='\s+')
df3344.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']
df3345 = pd.read_csv("Fig.3(d)\data_3345.dat",engine='python',skiprows=34,header=None,sep='\s+')
df3345.columns = ['IPS','B (T)','z_parameter (none)','lockin 1','Keithley 1','Keithley 2','processed dIdV']

# %%
fig3 = plt.figure(figsize=(9,9))

ax3a = fig3.add_axes([0.1, 0.6, 0.3, 0.3])
ax3b = fig3.add_axes([0.03, 0.12, 0.45, 0.45])

ax3c = fig3.add_axes([0.6, 0.61, 0.3, 0.3])
ax3d = fig3.add_axes([0.6, 0.2, 0.3, 0.3])

ax3a.imshow(mpimg.imread('Fig.3(a)/(a).png'))
ax3a.set_title('(a)')
ax3a.axis('off')

ax3b.imshow(mpimg.imread('Fig.3(a)/(b).png'))
ax3b.set_title('(b)')
ax3b.axis('off')

ax3c.plot(df3332['B (T)'],df3332['Keithley 1']*1000,df3333['B (T)'],df3333['Keithley 1']*1000)
ax3c.legend(['-->','<--'])
ax3c.set_xlabel('B (T)')
ax3c.set_ylabel('I (nA)')
ax3c.set_title('(c)')
ax3c.set_xlim(-0.2,0.2)


ax3d.plot(df3344['B (T)'],df3344['Keithley 1']*1000,df3345['B (T)'],df3345['Keithley 1']*1000)
ax3d.legend(['-->','<--'])
ax3d.set_xlabel('B (T)')
ax3d.set_ylabel('I (nA)')
ax3d.set_title('(d)')
ax3d.set_xlim(-0.2,0.2)

datacursor()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
dff4d = pd.read_csv("Fig.4\\run_27.txt",engine='python',skiprows=1,header=None,sep='\s+', dtype=np.float64)
dff4d.columns = ['t','mx','my','mz','Bx','By','Bz','Counter']

# %%
fig4 = plt.figure(figsize=(9,9))

ax4a = fig4.add_axes([0.1, 0.7, 0.8, 0.25])
ax4b = fig4.add_axes([0.12, 0.33, 0.35, 0.35])
ax4c = fig4.add_axes([0.5, 0.3, 0.4, 0.4])
ax4d = fig4.add_axes([0.1, 0.01, 0.8, 0.28])

ax4a.imshow(mpimg.imread('Fig.4/(a).png'))
ax4a.set_title('(a)')
ax4a.axis('off')

ax4b.imshow(mpimg.imread('Fig.4/(b).png'))
ax4b.set_title('(b)')
ax4b.axis('off')

ax4c.imshow(mpimg.imread('Fig.4/(c).png'))
ax4c.set_title('(c)')
ax4c.axis('off')

theta = 20*math.pi/180;

uf4 = dff4d['Counter']*(10**9)-500;
Buf4 = dff4d['Bx']*1000*math.cos(theta) + dff4d['By']*1000*math.sin(theta);
Bvf4 = -dff4d['Bx']*1000*math.sin(theta) + dff4d['By']*1000*math.cos(theta);
Bzf4 = dff4d['Bz']*1000;
Bf4 = ((Buf4**2 + Bvf4**2 + Bzf4**2)**0.5)

ax4d.plot(uf4,Buf4,uf4,Bvf4,uf4,Bzf4,uf4,Bf4)
ax4d.legend(['Bu','Bv','Bz','|B|'])
ax4d.set_xlabel('u (nm)')
ax4d.set_ylabel('B (mT)')
ax4d.set_title('(d)')

datacursor()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# <font color=black size=2>**Figure 1**</font>. (a) Scanning electron microscope (SEM) image of an N-(F,F)-N device A. The two CoFe strips are insulated from the nanowire by the native oxide layer on the nanowire. The direction of the external magnetic field B is indicated by an arrow. (b) Schematic of measurement setup. All data shown in this figure are acquired by DC measurement. (c) Current as a function of external magnetic field using the source-drain bias voltage Vsd = 2mV and the gate voltage Vg = 1.05V. Directions of magnetic field sweep are indicated by arrows. (d) Magnetic field scan taken at Vsd = 2mV and Vg = 1.1V.
#
# <font color=black size=2>**Figure 2**</font>. (a) Scanning electron microscope (SEM) image of N-F-F-N device B. The direction of the applied magnetic field is illustrated in the figure. (b) Schematic of device B. Data shown in this figure are acquired by lock-in technique. (c, d) Local and non-local signals from magnetic field scan taken at 0.1mV AC voltage bias, zero DC voltage bias and Vg = 1.2V in configuration 1. (e, f) Local and non-local signals from magnetic field scan in configuration 2 taken at 0.1mV AC voltage bias, 1 mV DC voltage bias and Vg = 1.35V. For (c) and (e), the conductance incudes the conductance from the measurement circuit. For (d) and (f), the voltage is the AC voltage measured by lock-in.
#
# <font color=black size=2>**Figure 3**</font>. (a) Scanning electron microscope (SEM) image of an F-F device C. The direction of the applied magnetic field is illustrated in the figure. (b) Schematic of measurement setup. All data shown in this figure are acquired by DC measurement. (c) Plot of a magnetic field scan taken at Vsd = 0.1mV and Vg = 0V. (d) Magnetic field scan taken at Vsd = 0.1mV and Vg = 0.08V. The sign of the hysteresis is reversed compared to plot (c).
#
# <font color=black size=2>**Figure 4**</font>. (a) Simulated magnetization of two microstrips with the external field strength in the y-direction (Bext,y) as indicated. Colors associated with the direction of the vector and the coordinate system used in this figure are presented on the right hand side. The angle θ between the x-axis and the nanowire coordinate u is taken to be 20º.  (b) Stray field created by the micro-magnets for configurations presented in (a). (c) Hysteresis loop of the two micro-strips. The colors of the dots in this plot correspond to the colors of the indicated applied field values in (a-b). (d) The stray field in the nanowire for parallel up magnetization (achieved when Bext,y=75 mT) as function of u.

# %% [markdown]
#          Hysteretic magnetoresistance in nanowire devices due to stray fields induced by micromagnets
#
#            Y. Jiang1, E. de Jong2, V. van de Sande2, S. Gazibegovic2, G. Badawy2, E.P.A.M. Bakkers2,
#                                                S.M. Frolov1
#
#                     1 University of Pittsburgh, Pittsburgh, Pennsylvania 15260, USA
#                     2 Eindhoven University of Technology, 5600 MB, Eindhoven, Netherlands
#
# <font color=black size=2>**Abstract**</font>
#
# We study hysteretic magnetoresistance in InSb nanowires due to stray magnetic fields from CoFe micromagnets. Devices without any ferromagnetic components show that the magnetoresistance of InSb nanowires commonly exhibits either a local maximum or local minimum at zero magnetic field. Switching of local magnetizations then results in positive or negative hysteretic magnetoresistance as conductance maxima or minima shift with respect to the global external field. Stay fields are found to be in the range of tens of millitesla, a scale similar to that over which the nanowire magnetorestance develops. This coincidence yields spin valve-like hysteretic signals. However, devices where CoFe micromagnets are not in contact with the nanowire show similar hysteresis to those which ferromagnetic ohmic contacs, pointing at the stray field origin of the signal. The use of locally varying magnetic fields may bring new ideas for Majorana circuits in which nanowire networks require control over field orientation at the nanoscale.
#
# <font color=black size=2>**Introduction**</font>
#
# InSb nanowires demonstrate ballistic transport [1] and strong spin orbit interaction (SOI) [2, 3]. These properties make them promising for the realization of Majorana bound states (MBS) in hybrid semiconductor-superconductor structures. In Majorana experiments that are typically performed in an external global magnetic field, transport measurements show zero bias conductance peaks, which are investigated as signatures of MBS [4]. Magnetic materials may replace the global magnetic field in MBS experiments and provide additional design and architecture freedom for Majorana-based quantum circuits [5-7]. It may be possible to turn off the external magnetic field after the micro-magnets are magnetized in a desired configuration. The stray field profile may in principle reproduce a helical pattern of spin-orbit field and therefore broaden the material selection for MBS experiments to those without intrinsic spin-orbit interaction [8]. The usefulness of micromagnets for quantum devices is not limited to Majorana experiments, as micromagnets have been used in quantum dot and spin qubit experiments [9-11].
# In this article, by integrating ferromagnetic components into nanowire devices, we show that the local stray magnetic field can influence conductance of InSb nanowires. For our most conclusive experiments, we fabricate InSb nanowire devices with non-magnetic ohmic contacts. Two ferromagnetic micro-strips with different dimensions are deposited beside the InSb nanowire but without forming ohmic contacts. The coercivity of microstrips and stray field inside the nanowire can be estimated from switches of magnetoresistance and shift of the local magnetoresistance maximum or minimum respectively. The coercivity difference of the two ferromagnetic microstrips is of order 10mT, and the stray field within the nanowire is of order tens of millitesla. We also perform magnetoresistance measurements on devices of similar micromagnet geometry but in which the ferromagnets do make ohmic contact to the nanowire. We observe similar hysteresis which can be fully explained by the local stray field effects. In future work, it may be feasible to dispense with the external magnetic field in MBS experiments. However, in devices studied here the main direction of the stray field produced by the ferromagnetic micro-strips is not along the nanowire, which is needed for the realization of MBS. By careful design and arrangement of ferromagnetic microstrips, a required profile of local stray field can be generated [6].
#
# <font color=black size=2>**Device Fabrication Methods**</font>
#
# We fabricate four types of devices for our experiments: N-(F,F)-N; N-N; N-F-F-N; and F-F. For N-(F,F)-N devices, there are two non-magnetic ohmic contacts labeled N and two ferromagnetic microstrips (F, F) not in ohmic contact with the nanowire. For N-F-F-N and F-F devices, there are ferromagnetic ohmic contacts. There are two types of nanowires used and for more details of the nanowires, we suggest referring papers from our colleagues [12, 13]. Long stemless InSb nanowires are used for N-(F,F)-N, N-N and N-F-F-N devices; short stemmed nanowires are used for F-F devices. Nanowires are placed on a back-gate chip, enabling chemical potential tuning.  There are two types of back-gate chips used in our experiment. The first type is using highly doped silicon with a layer of thermally formed silicon oxide as the gate. For the second type, thin Ti/Au (1nm Ti, 10nm Au) layers are deposited on an undoped silicon chip. A10nm HfOx layer is deposited using atomic layer deposition (ALD) on the metal layers. This second type of gate chips improves the charge stability of nanowire devices. To fabricate ferromagnetic ohmic contacts, we use sulfur passivation to remove the native oxide on the nanowires before the deposition of the metals by electron beam evaporation of CoFeB (micromagnets F). The electron beam evaporator cannot preserve the atomic ratio of CoFeB pellets (55/30/15 before deposition) and the deposited metal is mostly CoFe [14]. Before the deposition of Ti/Au (non-magnetic N contacts), argon milling is used to clean the native oxide on the nanowires. For N-(F,F)-N devices, we emphasize that there are only Ti/Au ohmic contacts formed and the ferromagnetic micro-strips are intentionally deposited either beside the nanowires or on top of nanowires but without removing the native oxide layer thus preventing ohmic contact. In contrast, for N-F-F-N and F-F devices, sulfur passivation is performed for ferromagnetic contacts as well as for non-magnetic contacts. Another fabrication consideration to point out is the choice of thickness for CoFe. For N-F-F-N and F-F devices, to overcome the thickness of the nanowire (typically around 100nm), the thickness of CoFe is around 70nm and we perform deposition at a finite angle (typically 50º with respect to the chip surface, see supplementary materials for details). For N-(F,F)-N devices, since we do not need to cover the nanowire, the thickness of the CoFe strips is thinner: around 40 nm. Our micromagnetic simulations indicate that this smaller thickness may facilitate sharper magnetization switching because it makes the strip closer to the single domain regime.
# Experimental Results
# We demonstrate the spin valve-like signal due to stray fields first using N-(F,F)-N devices (Fig. 1(a)). The measurement is performed in a dilution refrigerator with a base temperature of 40 mK. We apply a DC voltage bias across the non-magnetic N contacts and measure current through the nanowire, as shown in Fig. 1(b). Magnetic field is applied parallel to the easy axis of the CoFe strips, in the case of device A presented in Fig. 1 there is an about 70º angle between the direction of the field and the nanowire. The two CoFe microstrips are expected to have different coercivities because of their different widths, so the magnetoresistance of the device is expected to exhibit two sharp switches for each magnetic field orientation. Fig. 1(c) shows a representative measurement. Indeed, there are hysteretic switches at -42mT ± 1mT, -63mT ± 1mT, 43mT ± 1mT and 53mT ± 1mT. We also notice that the current maximum (minimum of magnetoresistance) is shifted away from zero field. For the red curve it is at -25mT ± 1mT and for the blue curve it is at 35mT ± 1mT. Thus the local stray field in this measurement is on the order of 30 mT. For different scans, these numbers do not remain the same due to the stochastic nature of switches.
#
# By adjusting the gate voltage or bias voltage, it is possible to change the sign of the hysteresis, as shown in Fig. 1(d). The magnetoresistance of InSb nanowires may have a local maximum or a local minimum at zero magnetic field. Fig. 1(c,d) show a transition from minimum to maximum resistance resulting in sign change of the hysteresis. We also need to point out that conductance jumps due to local charge rearrangement are also commonly observed. To distinguish magnetic and charge jumps, we look for the approximate symmetry around zero field and for approximate reproducibility from sweep to sweep of the external magnetic field. In Fig. 1(d), the red and blue curves do not overlap in the range from -0.2T to -0.1T, while they do overlap in the positive field direction. This may be due to an irreproducible charge jump. We present more hysteretic magnetoresistance plots to justify that the observed hysteresis is not from charge jumps in supplementary materials.
# In supplementary materials we also present magnetoresistance measurements on a device without any ferromagnetic components (N-N). The magnetoresistance of this device shows a peak or a dip feature around zero magnetic field and no hysteresis. This confirms that the hysteretic magnetoresistance originates from switching in micromagnets and that the electromagnet used to generate the external magnetic field is not hysteretic.
#
# We find similar hysteretic signals in N-F-F-N devices such as device B shown in Figs. 2(a,b). The geometry of the CoFe contacts is similar to those used in device A, but now the ferromagnets are in ohmic contact with the nanowire. The four-terminal contact geometry allows us to measure local current and non-local voltage simultaneously. Standard low-frequency lock-in technique is used. The direction of the external magnetic field is about 5 degrees away from perpendicular to the nanowire. We use two measurement configurations. First, we apply voltage across contacts 1(N) and 3(F). The local signal is the current through contact 1 and contact 3. The non-local signal is the voltage across contacts 2(N) and 4(F). In this configuration presented in Figs. 2(c,d)  we observe hysteretic signals non-locally without observing a clear local hysteresis and the maximum of local signal at zero external field. Such a pattern is expected from a basic non-local spin valve where only spin-polarized transport in between the two ferromagnets should exhibit hysteretic switching. However, measurements in the second configuration are inconsistent with such non-local spin valve picture. Voltage bias is now applied across contacts 2 and 4. Using this setup, we we observe strong hysteresis in the local signal (Figs. 2(e,f)). In the non-local signal, the minimum of the signal is centered at zero field, though small hysteretic loops appear symmetrically around zero field as well. In the supplementary materials we show more data for both measurement setups. Consistent with those devices without CoFe contacts, the sign of the hysteresis can also be modulated by adjusting gate voltages and bias voltages in device B, in contradiction to the simple spin valve picture. The CoFe contacts of device B are expected to produce similar local stray fields as in device A. Therefore, we conclude that the stray field is more likely the origin of the observed hysteresis as opposed to spin-polarized transport. It should be pointed out that plots without clear hysteresis are common which may be due to charge jumps and less sharp magnetization switches in this device. Nevertheless, the non-local hysteretic signals in device B are consistent with the hysteretic signals appearing in device A in terms of their extent in magnetic field.
#
# As additional experiments, we perform DC measurements using devices with only two ferromagnetic contacts (F-F devices). One of these devices is shown in Fig. 3(a) and the measurement setup is shown in Fig. 3(b). Fig. 3(c,d) shows two representative magnetoresistance plots. The features of the hysteresis are consistent with what we show in Figs. 1 and 2. Thus, also in this local spin valve configuration the hysteretic switching magnetoresistance is consistent with the effect of stray magnetic fields from the microstrips.
#
# <font color=black size=2>**Micromagnetic simulations**</font>
#
# We also perform simulations of stray fields to compare with experimental results. For more realistic results, we use the geometry of device A including the shapes of CoFe strips and the orientation of the nanowire. In the simulations the two CoFe microstrips have dimensions of 150nm x 4500nm x 40nm and 300nm x 3000nm x 40nm respectively. Simulations are carried out using MuMax3 package [15]. The magnetic parameters of CoFe vary in a broad range [16-19] and the magnetic parameters of our CoFe films are not known beyond data in Figs. 1-3. For simulations we therefore use parameters known for Co which we expect to give values close to CoFe. We set the magnetic saturation to be 1.44×106 A/m, the first order uniaxial anisotropy constant to be 4.1×10-1 J/m3, the second order uniaxial anisotropy constant to be 1.4×10-1 J/m3, the exchange constant to be 3×10-11 J/m, and the phenomenological damping constant to be 0.01. We use a 10nm cubic cell size in the interest of reducing computation time, though the exchange length of CoFe is likely smaller than 10nm. Magnetization patterns in Fig. 4(a) show that it is possible to realize configurations in which the two microstrips are magnetized parallel or anti-parallel. Fig. 4(b) shows local stray field produced by the two strips at four different values of the external magnetic field. The simulations reproduce the experimentally observed double-switch hysteretic loops (Fig. 1(c) and Fig. 4(c)). The anti-parallel configurations appear at around ±50mT, which is consistent with what we observe experimentally. In Fig. 4(d), we show the stray field along the nanowire when the strips are magnetized in parallel (+y direction). The coordinate along the nanowire is u, and v is perpendicular to nanowire. The position u = 0 is the middle of the gap between the two CoFe strips. To generate these plots, we take the average of the stray field inside the hexagonal nanowire cross section with the size of 100 nm. As expected, the field in the v direction (the direction perpendicular to the nanowire) is the largest. However, the field in the u and z directions is comparable. The maximum stray field inside the nanowire is close to 60mT. The stray field profile is very ununiform due to the lack of symmetry of the two micro-strips. Moreover, our data from measurements indicate smaller stray field inside the nanowire. It is likely that the magnetic saturation used in our simulation is too large. Another point to notice is the sudden jump in the Bz field. The origin of this jump is not clear and it may come from numerical errors. The strips are 40nm thick but the cell size is 10nm, which may be not appropriate for the z direction.
#
# <font color=black size=2>**Alternative Explanations**</font>
#
# When micromagnets are in ohmic contact with the nanowire, spin injection and pure spin currents can produce hysteretic signals such as in our N-F-F-N and F-F devices [20-22]. We already discussed above that while spin injection may be taking place, it is challenging to separate its effect from the effect of local stray fields since both effects manifest in similar fashion (see Figs. 2 and 3). Besides directly injecting spin polarized current using ferromagnetic ohmic contacts, there are other methods to induce hysteretic magnetoresistance that use the exchange field from ferromagnetic insulators (or metals) [23] which is expected to have a significantly smaller effect on magnetoresistance than the stray field effect. Another possibility is magneto-Coulomb effect [24, 25] which similarly to the local stray field effect requires only a single ferromagnet to manifest.
#
# <font color=black size=2>**Conclusion and Future Work**</font>
#
# Our experiments demonstrate the influence of the stray fields produced by CoFe microstrips and contacts on transport in InSb nanowires. We observe that the stray field effect can mimic spin polarized transport signatures such as hysteretic transport. For future work, by careful design of ferromagnetic microstrips, we shall aim to realize stray field profiles with field along the nanowire and search for MBS in a hybrid superconductor-semiconductor system. The fields found in the simulation so far are too small and non-uniform for MBS experiments, thus ways to enhance and optimize field profiles can be explored further.
#
# <font color=black size=2>**Further Reading**</font>
#
# For the readers who are interested in MBS devices without external magnetic field, we suggest further reading of these articles [6, 26, 27]. In these articles, magnetic texture is produced by magnetic strips or an array of magnetic tunnel junctions. MBS is believed to exist in these devices and even braiding is possible. For the reader who has interest in the applications outside MBS, measurement with a Hall bar [28] is an example.
#
# <font color=black size=2>**Duration and Volume of Study**</font>
#
# This article is written based on more than 6500 datasets from 8 cool downs of dilution fridges. For each cool down, we can measure several devices. We measured 19 N-(F,F)-N devices, 1 N-N device, 20 N-F-F-N devices and 9 F-F devices. Among them, we observed reproducible hysteretic magnetoresistance in 17 devices. The yield of the devices is limited by fabrication and occasional static electricity damage of devices.
#
# <font color=black size=2>**Author Contributions**</font>
#
# Y.J. performed device fabrication and measurements.  G.B., S.G. and E.B. provided InSb nanowires. Y.J. and S.F. analyzed the experimental data. E.d.J. and V.v.d.S. performed micromagnetics simulations. Y.J. and S.F. wrote the manuscript with contributions from all co-authors.
# Acknowledgements
# We thank V. Pribiag and Z. Yang for discussions. Work supported by the Department of Energy DE-SC-0019274.
#
# [1] I. van Weperen, S.R. Plissard, E.P. Bakkers, S.M. Frolov, L.P. Kouwenhoven, Quantized conductance in an InSb nanowire, Nano letters, 13 (2012) 387-391.
#
# [2] I. van Weperen, B. Tarasinski, D. Eeltink, V.S. Pribiag, S.R. Plissard, E.P.A.M. Bakkers, L.P. Kouwenhoven, M. Wimmer, Spin-orbit interaction in InSb nanowires, Physical Review B, 91 (2015).
#
# [3] J. Kammhuber, Spin-orbit interaction in ballistic nanowire devices, 2017.
#
# [4] V. Mourik, K. Zuo, S.M. Frolov, S.R. Plissard, E.P.A.M. Bakkers, L.P. Kouwenhoven, Signatures of Majorana Fermions in Hybrid Superconductor-Semiconductor Nanowire Devices, Science, 336 (2012) 1003-1007.
#
# [5] Y. Oreg, G. Refael, F. von Oppen, Helical liquids and Majorana bound states in quantum wires, Physical review letters, 105 (2010) 177002.
#
# [6] N. Mohanta, T. Zhou, J.-W. Xu, J.E. Han, A.D. Kent, J. Shabani, I. Žutić, A. Matos-Abiague, Electrical Control of Majorana Bound States Using Magnetic Stripes, Physical Review Applied, 12 (2019) 034048.
#
# [7] Y. Liu, S. Vaitiekėnas, S. Martí-Sánchez, C. Koch, S. Hart, Z. Cui, T. Kanne, S.A. Khan, R. Tanta, S. Upadhyay, M.E. Cachaza, C.M. Marcus, J. Arbiol, K.A. Moler, P. Krogstrup, Semiconductor–Ferromagnetic Insulator–Superconductor Nanowires: Stray Field and Exchange Field, Nano Letters, 20 (2020) 456-462.
#
# [8] S. Turcotte, S. Boutin, J. Camirand Lemyre, I. Garate, M. Pioro-Ladrière, Optimized micromagnet geometries for Majorana zero modes in low g-factor materials,  arXiv e-prints, 2019.
#
# [9] G. Fábián, P. Makk, M.H. Madsen, J. Nygård, C. Schönenberger, A. Baumgartner, Magnetoresistance engineering and singlet/triplet switching in InAs nanowire quantum dots with ferromagnetic sidegates, Physical Review B, 94 (2016.
#
# [10] X. Mi, M. Benito, S. Putz, D.M. Zajac, J.M. Taylor, G. Burkard, J.R. Petta, A coherent spin–photon interface in silicon, Nature, 555 (2018) 599-603.
#
# [11] M. Pioro-Ladrière, T. Obata, Y. Tokura, Y.S. Shin, T. Kubo, K. Yoshida, T. Taniyama, S. Tarucha, Electrically driven single-electron spin resonance in a slanting Zeeman field, Nature Physics, 4 (2008) 776-779.
#
# [12] S.R. Plissard, D.R. Slapak, M.A. Verheijen, M. Hocevar, G.W.G. Immink, I. van Weperen, S. Nadj-Perge, S.M. Frolov, L.P. Kouwenhoven, E.P.A.M. Bakkers, From InSb Nanowires to Nanocubes: Looking for the Sweet Spot, Nano Letters, 12 (2012) 1794-1798.
#
# [13] G. Badawy, S. Gazibegovic, F. Borsoi, S. Heedt, C.-A. Wang, S. Koelling, M.A. Verheijen, L.P. Kouwenhoven, E.P.A.M. Bakkers, High Mobility Stemless InSb Nanowires, Nano Letters, 19 (2019) 3575-3582.
#
# [14] C. Bureau-Oxton, Fabrication de nanoaimants pour le contrôle rapide d'un spin électronique dans une boîte quantique double, Université de Sherbrooke, 2014.
#
# [15] A. Vansteenkiste, J. Leliaert, M. Dvornik, M. Helsen, F. Garcia-Sanchez, B. Van Waeyenberge, The design and verification of MuMax3, AIP advances, 4 (2014) 107133.
#
# [16] Y. Fukuma, Z. Lu, H. Fujiwara, G.J. Mankey, W.H. Butler, S. Matsunuma, Strong uniaxial magnetic anisotropy in CoFe films on obliquely sputtered Ru underlayer, Journal of Applied Physics, 106 (2009) 076101.
#
# [17] T.H. Kim, Y.H. Jeong, J.S. Kang, Structural and magnetic properties of CoFe alloy films, Journal of Applied Physics, 81 (1997) 4764-4766.
#
# [18] C.L. Platt, A.E. Berkowitz, D.J. Smith, M.R. McCartney, Correlation of coercivity and microstructure of thin CoFe films, Journal of Applied Physics, 88 (2000) 2058-2062.
#
# [19] Q. Mustaghfiroh, C. Kurniawan, D. Djuhana, Magnetization Dynamic Analysis of Square Model CoFe and CoFeB Ferromagnetic Materials Using Micromagnetic Simulation, IOP Conference Series: Materials Science and Engineering, 553 (2019) 012009.
#
# [20] S. Heedt, C. Morgan, K. Weis, D.E. Burgler, R. Calarco, H. Hardtdegen, D. Grutzmacher, T. Schapers, Electrical spin injection into InN semiconductor nanowires, Nano Lett, 12 (2012) 4437-4443.
#
# [21] H. Kum, J. Heo, S. Jahangir, A. Banerjee, W. Guo, P. Bhattacharya, Room temperature single GaN nanowire spin valves with FeCo/MgO tunnel contacts, Applied Physics Letters, 100 (2012).
#
# [22] J. Tarun, S. Huang, Y. Fukuma, H. Idzuchi, Y. Otani, N. Fukata, K. Ishibashi, S. Oda, Demonstration of spin valve effects in silicon nanowires, Journal of Applied Physics, 109 (2011).
#
# [23] Y. Liu, S. Vaitiekėnas, S. Martí-Sánchez, C. Koch, S. Hart, Z. Cui, T. Kanne, S.A. Khan, R. Tanta, S. Upadhyay, M.E. Cachaza, C.M. Marcus, J. Arbiol, K.A. Moler, P. Krogstrup, Semiconductor–Ferromagnetic Insulator–Superconductor Nanowires: Stray Field and Exchange Field, DOI 10.1021/acs.nanolett.9b04187(2019).
#
# [24] S.J. van der Molen, N. Tombros, B.J. van Wees, Magneto-Coulomb effect in spin-valve devices, Physical Review B, 73 (2006).
#
# [25] F. Zwanenburg, D. Van der Mast, H. Heersche, L. Kouwenhoven, E. Bakkers, Electric field control of magnetoresistance in InP nanowires with ferromagnetic contacts, Nano letters, 9 (2009) 2704-2709.
#
# [26] A. Matos-Abiague, J. Shabani, A.D. Kent, G.L. Fatin, B. Scharf, I. Žutić, Tunable magnetic textures: From Majorana bound states to braiding, Solid State Communications, 262 (2017) 1-6.
#
# [27] G.L. Fatin, A. Matos-Abiague, B. Scharf, I. Žutić, Wireless Majorana bound states: From magnetic tunability to braiding, Physical review letters, 117 (2016) 077002.
#
# [28] D. Lachance-Quirion, J. Camirand Lemyre, L. Bergeron, C. Sarra-Bournet, M. Pioro-Ladrière, Magnetometry of micro-magnets with electrostatically defined Hall bars, Applied Physics Letters, 107 (2015) 223103.
#
# [29] Z. Yang, B. Heischmidt, S. Gazibegovic, G. Badawy, D. Car, P.A. Crowell, E.P.A.M. Bakkers, V.S. Pribiag, Spin Transport in Ferromagnet-InSb Nanowire Quantum Devices, Nano Letters, 20 (2020) 3232-3239.
